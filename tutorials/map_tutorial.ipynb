# %% [markdown]
# <a href="https://colab.research.google.com/github/oonuma0930/argoverse/blob/master/tutorials/map_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this tutorial, we'll demonstrate the Argoverse 2.0 map API, and visualize some of the map data.

# %%
# !pip install av2
# !git clone https://github.com/oonuma0930/argoverse


from argparse import Namespace
from pathlib import Path
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: av2 in /usr/local/lib/python3.10/dist-packages (0.2.1)
# Requirement already satisfied: av in /usr/local/lib/python3.10/dist-packages (from av2) (10.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from av2) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from av2) (1.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from av2) (3.7.1)
# Requirement already satisfied: nox in /usr/local/lib/python3.10/dist-packages (from av2) (2023.4.22)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from av2) (0.56.4)
# Requirement already satisfied: numpy>=1.21.5 in /usr/local/lib/python3.10/dist-packages (from av2) (1.22.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from av2) (4.7.0.72)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from av2) (1.5.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from av2) (9.0.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from av2) (3.6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from av2) (13.3.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from av2) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->av2) (2.8.2)
# Requirement already satisfied: argcomplete<4.0,>=1.9.4 in /usr/local/lib/python3.10/dist-packages (from nox->av2) (3.1.1)
# Requirement already satisfied: colorlog<7.0.0,>=2.6.1 in /usr/local/lib/python3.10/dist-packages (from nox->av2) (6.7.0)
# Requirement already satisfied: virtualenv>=14 in /usr/local/lib/python3.10/dist-packages (from nox->av2) (20.23.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->av2) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->av2) (67.7.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->av2) (2022.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj->av2) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->av2) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->av2) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->av2) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->av2) (1.16.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=14->nox->av2) (0.3.6)
# Requirement already satisfied: filelock<4,>=3.12 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=14->nox->av2) (3.12.0)
# Requirement already satisfied: platformdirs<4,>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=14->nox->av2) (3.6.0)
# Cloning into 'argoverse'...
# remote: Enumerating objects: 1406, done.
# remote: Counting objects: 100% (1406/1406), done.
# remote: Compressing objects: 100% (680/680), done.
# remote: Total 1406 (delta 639), reused 1395 (delta 634), pack-reused 0
# Receiving objects: 100% (1406/1406), 6.64 MiB | 19.66 MiB/s, done.
# Resolving deltas: 100% (639/639), done.

# %%
# path to where the logs live
dataroot = "/content/argoverse/"
#!rm -rf /content/argoverse
# unique log identifier
log_id = "0000b0f9-99f9-4a1f-a231-5be9e4c523f7"
args = Namespace(**{"dataroot": Path(dataroot), "log_id": Path(log_id)})
# !ls
# Out:
# argoverse  sample_data

# %%
import argparse
from pathlib import Path
from typing import List

import matplotlib

import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.axes_grid1 import make_axes_locatable

import av2.geometry.polyline_utils as polyline_utils
import av2.rendering.vector as vector_plotting_utils
from av2.datasets.sensor.av2_sensor_dataloader import AV2SensorDataLoader
from av2.map.map_api import ArgoverseStaticMap, LaneSegment

# %% [markdown]
# First, we'll plot the lane graph and crosswalks, with crosswalks colored purple, and the lanes colored green.

# %%
# scaled to [0,1] for matplotlib.
PURPLE_RGB = [201, 71, 245]
PURPLE_RGB_MPL = np.array(PURPLE_RGB) / 255

DARK_GRAY_RGB = [40, 39, 38]
DARK_GRAY_RGB_MPL = np.array(DARK_GRAY_RGB) / 255

# %%
def single_log_teaser(args: argparse.Namespace) -> None:
    """
    For a single log, render all local crosswalks in green, and pedestrian crossings in purple,
    in a bird's eye view.
    """
    #log_map_dirpath = Path(args.dataroot) / args.log_id / "map.json"
    log_map_dirpath = Path(args.dataroot) / args.log_id
    print(log_map_dirpath)
    #!cat /content/argoverse/0000b0f9-99f9-4a1f-a231-5be9e4c523f7/map.json
    avm = ArgoverseStaticMap.from_map_dir(log_map_dirpath, build_raster=False)

    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot()

    for _, ls in avm.vector_lane_segments.items():
        # right_ln_bnd
        # left_ln_bnd
        vector_plotting_utils.draw_polygon_mpl(ax, ls.polygon_boundary, color="g", linewidth=0.5)
        vector_plotting_utils.plot_polygon_patch_mpl(ls.polygon_boundary, ax, color="g", alpha=0.2)

    # plot all pedestrian crossings
    for _, pc in avm.vector_pedestrian_crossings.items():
        vector_plotting_utils.draw_polygon_mpl(ax, pc.polygon, color="m", linewidth=0.5)
        vector_plotting_utils.plot_polygon_patch_mpl(pc.polygon, ax, color="m", alpha=0.2)

    plt.show()

# %%
single_log_teaser(args)
# Out:
# /content/argoverse/0000b0f9-99f9-4a1f-a231-5be9e4c523f7

# %%
def visualize_raster_layers(args: argparse.Namespace) -> None:
    """Visualize the ground surface height/elevation map, w/ a colorbar indicating the value range.

    Also, visualize side-by-side plots of the 3 raster arrays -- ground height, drivable area, ROI.
    """
    #log_map_dirpath = Path(args.dataroot) / args.log_id / "map"
    log_map_dirpath = Path(args.dataroot) / args.log_id
    avm = ArgoverseStaticMap.from_map_dir(log_map_dirpath, build_raster=True)

    height_array = avm.raster_ground_height_layer.array
    ax = plt.subplot()
    plt.title("Ground surface height (@ 30 centimeter resolution).")
    img = plt.imshow(np.flipud(height_array))

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    plt.colorbar(img, cax=cax)
    plt.show()

    plt.figure(figsize=(20, 10))
    plt.subplot(1, 3, 1)
    plt.imshow(np.flipud(height_array))
    plt.title("Ground Surface Height")

    plt.subplot(1, 3, 2)
    da_array = avm.raster_drivable_area_layer.array
    plt.imshow(np.flipud(da_array))
    plt.title("Drivable Area (rasterized \nfrom vector polygons)")

    plt.subplot(1, 3, 3)
    roi_array = avm.raster_roi_layer.array
    plt.imshow(np.flipud(roi_array))
    plt.title("Region of Interest (ROI)")
    plt.show()

# %%
visualize_raster_layers(args)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-45-230f213fad6d> in <cell line: 1>()
# ----> 1 visualize_raster_layers(args)
#
# <ipython-input-44-9d64eceb3a36> in visualize_raster_layers(args)
#       6     #log_map_dirpath = Path(args.dataroot) / args.log_id / "map"
#       7     log_map_dirpath = Path(args.dataroot) / args.log_id
# ----> 8     avm = ArgoverseStaticMap.from_map_dir(log_map_dirpath, build_raster=True)
#       9
#      10     height_array = avm.raster_ground_height_layer.array
#
# /usr/local/lib/python3.10/dist-packages/av2/map/map_api.py in from_map_dir(cls, log_map_dirpath, build_raster)
#     381             static_map.raster_drivable_area_layer = DrivableAreaMapLayer.from_vector_data(drivable_areas=drivable_areas)
#     382             static_map.raster_roi_layer = RoiMapLayer.from_drivable_area_layer(static_map.raster_drivable_area_layer)
# --> 383             static_map.raster_ground_height_layer = GroundHeightLayer.from_file(log_map_dirpath)
#     384
#     385         return static_map
#
# /usr/local/lib/python3.10/dist-packages/av2/map/map_api.py in from_file(cls, log_map_dirpath)
#     124         ground_height_npy_fpaths = sorted(log_map_dirpath.glob("*_ground_height_surface____*.npy"))
#     125         if not len(ground_height_npy_fpaths) == 1:
# --> 126             raise RuntimeError("Raster ground height layer file is missing")
#     127
#     128         Sim2_json_fpaths = sorted(log_map_dirpath.glob("*___img_Sim2_city.json"))
#
# RuntimeError: Raster ground height layer file is missing

# %%
def plot_lane_segments(
    ax: matplotlib.axes.Axes, lane_segments: List[LaneSegment], lane_color: np.ndarray = DARK_GRAY_RGB_MPL
) -> None:
    """

    Args:
        ax:
        lane_segments:
    """
    for ls in lane_segments:
        pts_city = ls.polygon_boundary
        ALPHA = 1.0  # 0.1
        vector_plotting_utils.plot_polygon_patch_mpl(
            polygon_pts=pts_city, ax=ax, color=lane_color, alpha=ALPHA, zorder=1
        )

        for bound_type, bound_city in zip(
            [ls.left_mark_type, ls.right_mark_type], [ls.left_lane_boundary, ls.right_lane_boundary]
        ):
            if "YELLOW" in bound_type:
                mark_color = "y"
            elif "WHITE" in bound_type:
                mark_color = "w"
            else:
                mark_color = "grey"  # "b" lane_color #

            LOOSELY_DASHED = (0, (5, 10))

            if "DASHED" in bound_type:
                linestyle = LOOSELY_DASHED
            else:
                linestyle = "solid"

            if "DOUBLE" in bound_type:
                left, right = polyline_utils.get_double_polylines(
                    polyline=bound_city.xyz[:, :2], width_scaling_factor=0.1
                )
                ax.plot(left[:, 0], left[:, 1], mark_color, alpha=ALPHA, linestyle=linestyle, zorder=2)
                ax.plot(right[:, 0], right[:, 1], mark_color, alpha=ALPHA, linestyle=linestyle, zorder=2)
            else:
                ax.plot(
                    bound_city.xyz[:, 0],
                    bound_city.xyz[:, 1],
                    mark_color,
                    alpha=ALPHA,
                    linestyle=linestyle,
                    zorder=2,
                )

# %%
def argoverse2_sensor_dataset_teaser(args: argparse.Namespace, save_plot: bool = False) -> None:
    """
    Visualize both ego-vehicle poses and the per-log local vector map.

    Crosswalks are plotted in purple. Lane segments plotted in dark gray. Ego-pose in red.
    """
    loader = AV2SensorDataLoader(data_dir=args.dataroot, labels_dir=args.dataroot)

    fig = plt.figure(1, figsize=(10, 10))
    ax = fig.add_subplot(111)

    log_map_dirpath = Path(args.dataroot) / args.log_id / "map"

    avm = ArgoverseStaticMap.from_map_dir(log_map_dirpath, build_raster=False)

    # retain every pose first.
    traj_ns = loader.get_subsampled_ego_trajectory(args.log_id, sample_rate_hz=1e9)
    # now, sample @ 1 Hz
    traj_1hz = loader.get_subsampled_ego_trajectory(args.log_id, sample_rate_hz=1.0)
    med_x, med_y = np.median(traj_ns, axis=0)

    # Derive plot area from trajectory (with radius defined in infinity norm).
    view_radius_m = 50
    xlims = [med_x - view_radius_m, med_x + view_radius_m]
    ylims = [med_y - view_radius_m, med_y + view_radius_m]

    crosswalk_color = PURPLE_RGB_MPL
    CROSSWALK_ALPHA = 0.6
    for pc in avm.get_scenario_ped_crossings():
        vector_plotting_utils.plot_polygon_patch_mpl(
            polygon_pts=pc.polygon[:, :2],
            ax=ax,
            color=crosswalk_color,
            alpha=CROSSWALK_ALPHA,
            zorder=3,
        )

    plot_lane_segments(ax=ax, lane_segments=avm.get_scenario_lane_segments())

    ax.plot(traj_ns[:, 0], traj_ns[:, 1], color="r", zorder=4, label="Ego-vehicle pose")
    ax.scatter(
        traj_1hz[:, 0], traj_1hz[:, 1], 100, facecolors="none", edgecolors="r", zorder=4
    )  # marker='o', color="r")

    plt.axis("equal")
    plt.xlim(*xlims)
    plt.ylim(*ylims)
    plt.title(f"Log {args.log_id}")
    plt.axis("off")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
argoverse2_sensor_dataset_teaser(args)
